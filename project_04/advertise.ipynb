# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv(r"C:\Users\gupta\Downloads\DIM_PLAYER_MATCH.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data1=pd.read_csv(r"C:\Users\gupta\Downloads\DIM_PLAYER_MATCH.csv")
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
data=pd.read_csv(r"C:\Users\gupta\Downloads\advertising.csv")

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.describe().transpose()
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   15.1305   5.283892  1.6  11.000   16.00   19.050   27.0

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'Radio'}>],
#        [<Axes: title={'center': 'Newspaper'}>,
#         <Axes: title={'center': 'Sales'}>]], dtype=object)

# %%
data['TV'].value_counts().sort_index().plot(kind='line')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
data['Radio'].plot(kind='line')
plt.xlabel('Radio')
plt.ylabel('Sales (in million)')
plt.show()

# %%
data['Newspaper'].plot(kind='line',figsize=(10,10))
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.show()

# %%
x=data['Radio']
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['TV']
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['Newspaper']
y=data['Sales']
plt.scatter(x,y)

# %%
x=data['Radio']      
y=data['Sales']
plt.subplot(2, 2, 1)
plt.scatter(x,y)
x=data['TV']        
y=data['Sales']
plt.subplot(2,2,2 )
plt.scatter(x,y)
x=data['Newspaper']  
y=data['Sales']
plt.subplot(2, 2, 3)
plt.scatter(x,y)

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000
